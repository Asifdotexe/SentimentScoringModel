# %%
from src.senti_score import SentiScore

# %%
file_path = r"..\data\small_sample.csv"
rating_column = "overall"
review_column = "reviewText"

SentiScore(file_path, rating_column, review_column, text_processing_method='stem')
# Out:
# Reading data...
# Performing class rebalancing...
# Preprocessing data...
# Applying sentiment analysis...
# Analyzing sentiment scores...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       2 rating_column = "overall"
#       3 review_column = "reviewText"
# ----> 5 SentiScore(file_path, rating_column, review_column, text_processing_method='stem')
#
# File c:\Users\Asif Sayyed\Documents\GitHub\nlp-sentimental-analysis-on-amazon-reviews\code\src\senti_score.py:189, in SentiScore(file_path, rating_column, review_column, text_processing_method)
#     186 df = opinion_lexicon(df)
#     188 print("Analyzing sentiment scores...")
# --> 189 sentiment_score_analysis(df)
#     191 print("Pipeline completed successfully.")
#
# ...
